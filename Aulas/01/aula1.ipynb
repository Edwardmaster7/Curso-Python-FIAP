# %% [markdown]
# # Tipos Fundamentais

# %% [markdown]
# ## Numéricos

# %%
inteiro:int = 10
flutuante:float = 10.5

print(type(inteiro))
print(type(flutuante))
# Out:
# <class 'int'>
# <class 'float'>

# %% [markdown]
# # Loops

# %% [markdown]
# ## For

# %% [markdown]
# ### Usos de For

# %% [markdown]
# lista =

# %% [markdown]
# ### ![Exercício](img/img_exercicio.png)

# %%
from re import I


num:int = int(input("Insira a quantidade de números que deseja: "))

for i in range(1, num+1):
    if i % 3 == 0 and i % 5 == 0:
        print("FizzBuzz")
    elif i % 5 == 0:
        print("Buzz")
    elif i :
        print("Fizz")
    else:
        print(i)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 4
#       1 from re import I
# ----> 4 num:int = int(input("Insira a quantidade de números que deseja: "))
#       6 for i in range(1, num+1):
#       7     if i % 3 == 0 and i % 5 == 0:
#
# ValueError: invalid literal for int() with base 10: ''

# %% [markdown]
# # Funcões

# %%
CONTADOR = 0

def argumentos(inteiro:int, texto:str) -> dict:
    return {'inteiro':inteiro, 'texto': texto}

# %%
args = argumentos

# %% [markdown]
# # OOP

# %%
from meu_modulo import Tarefas
Tarefas()
